# %% [markdown]
# # Study based on Chapter 13

# %% [markdown]
# ### 13.1. Tutorial Overview
# In this section, we will develop a framework for grid searching SARIMA model hyperparameters for a given univariate time series forecasting problem. For more information on SARIMA for time series forecasting, see Chapter 5. We will use the implementation of SARIMA provided by the Statsmodels library. This model has hyperparameters that control the nature of the model performed for the series, trend and seasonality, specifically:
# * order: A tuple p, d, and q parameters for the modeling of the trend.
# * seasonal order: A tuple of P, D, Q, and m parameters for the modeling the seasonality
# * trend: A parameter for controlling a model of the deterministic trend as one of ‘n’, ‘c’, ‘t’, and ‘ct’ for no trend, constant, linear, and constant with linear trend, respectively

# %% [markdown]
# ### 13.2 Develop a Grid Search Framework

# %%
# grid search sarima hyperparameters
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import pandas as pd

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ###  13.1: Example of a function for making a SARIMA forecast

# %%
# one-step sarima forecast
def sarima_forecast(history, order=None, sorder=None, trend=None):
    # define model
    model = SARIMAX(history, order=order, seasonal_order=sorder, trend=trend,
    enforce_stationarity=False, enforce_invertibility=False)

    # fit model
    model_fit = model.fit(disp=False)

    # make one step forecast
    yhat = model_fit.predict(len(history), len(history))
    return yhat[0]

# %%
data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
print(data)
# data split
n_test = 4
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]

# %% [markdown]
# ### 11.3. Accessory functions

# %%
# root mean squared error or rmse
def measure_rmse(actual, predicted):
    return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test], data[-n_test:]

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
    predictions = list()
    
    # split dataset
    train, test = train_test_split(data, n_test)
    
    # seed history with training dataset
    history = [x for x in train]
    
    # step over each time-step in the test set
    for i in range(len(test)):        
        # fit model and make forecast for history
        yhat = sarima_forecast(history, cfg[0], cfg[1], cfg[2])
        
        # store forecast in list of predictions
        predictions.append(yhat)
        
        # add actual observation to history for the next loop
        history.append(test[i])
    
    # estimate prediction error
    error = measure_rmse(test, predictions)
    return error

# %% [markdown]
# x = 1
# oi

# %% [markdown]
# Essa é a lógica da função de treinamento:
#
# ```python
# loop 1:
#
# predictions = []
# train = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0]
# history = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0]
# test = [70.0, 80.0, 90.0, 100.0]
# predictions = [75]
#
# loop 2:
#
# predictions = [75]
# history = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0]
# test = [70.0, 80.0, 90.0, 100.0]
# predictions = [75, 85]
#
# loop 3:
#
# predictions = [75, 85]
# history = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0]
# test = [70.0, 80.0, 90.0, 100.0]
# predictions = [75, 85, 95]
#
# loop 4:
#
# predictions = [75, 85, 95]
# history = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0]
# test = [70.0, 80.0, 90.0, 100.0]
# predictions = [75, 85, 95, 105]
#
# rmse(test, predictions)
#
# ```

# %%
# create a set of sarima configs to try
def sarima_configs(seasonal=[0]):
    models = list()
    
    # define config lists
    p_params = [0, 1, 2]
    d_params = [0, 1]
    q_params = [0, 1, 2]
    t_params = ['n', 'c', 't', 'ct']
    P_params = [0, 1, 2]
    D_params = [0, 1]
    Q_params = [0, 1, 2]
    m_params = [0, 6, 12]#seasonal
    
    # create config instances
    for p in p_params:
        for d in d_params:
            for q in q_params:
                for t in t_params:
                    for P in P_params:
                        for D in D_params:
                            for Q in Q_params:
                                for m in m_params:
                                    models.append([(p,d,q), (P,D,Q,m), t])
    
    return models

# %%
config_list = sarima_configs()
len(config_list)
# Out:
# 1296

# %%
config_list[:10]
# Out:
# [[(0, 0, 0), (0, 0, 0, 0), 'n'],
#  [(0, 0, 0), (0, 0, 1, 0), 'n'],
#  [(0, 0, 0), (0, 0, 2, 0), 'n'],
#  [(0, 0, 0), (0, 1, 0, 0), 'n'],
#  [(0, 0, 0), (0, 1, 1, 0), 'n'],
#  [(0, 0, 0), (0, 1, 2, 0), 'n'],
#  [(0, 0, 0), (1, 0, 0, 0), 'n'],
#  [(0, 0, 0), (1, 0, 1, 0), 'n'],
#  [(0, 0, 0), (1, 0, 2, 0), 'n'],
#  [(0, 0, 0), (1, 1, 0, 0), 'n']]

# %%
# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
    result = None
    # convert config to a key
    key = str(cfg)
    # show all warnings and fail on exception if debugging
    if debug:
        result = walk_forward_validation(data, n_test, cfg)
    else:
        # one failure during model validation suggests an unstable config
        try:
            # never show warnings when grid searching, too noisy
            with catch_warnings():
                filterwarnings("ignore")
                result = walk_forward_validation(data, n_test, cfg)
        except:
            error = None
    # check for an interesting result
    if result is not None:
        print(' > Model[%s] %.3f' % (key, result))
    return (key, result)

# %%
# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
    scores = None
    if parallel:
        # execute configs in parallel
        executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
        tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
        scores = executor(tasks)
    else:
        scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
    
    # remove empty results
    scores = [r for r in scores if r[1] != None]
    
    # sort configs by error, asc
    scores.sort(key=lambda tup: tup[1])
    
    return scores

# %% [markdown]
# ### 13.4 Example of demonstrating the grid search infrastructure.

# %%
data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
print(data)
# data split
n_test = 4
# model configs
cfg_list = sarima_configs()
# grid search
scores = grid_search(data, cfg_list, n_test)
print('done')
# list top 3 configs
for cfg, error in scores[:3]:
    print(cfg, error)
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'n']] 85.732
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'c']] 37.914
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 't']] 6.103
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'n']] 85.732
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'ct']] 0.040
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 't']] 74.745
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'c']] 64.038
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'n']] 10.000
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'ct']] 1.529
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 't']] 5.542
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'n']] 9.165
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 't']] 2.427
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'n']] 6.103
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 't']] 6.103
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'n']] 3.129
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 't']] 3.129
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'ct']] 0.184
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'n']] 0.000
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 't']] 0.000
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'n']] 0.000
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 't']] 0.000
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'n']] 0.000
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'n']] 0.000
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 't']] 0.000
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 't']] 0.000
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'n']] 0.000
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'ct']] 0.000
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'c']] 0.010
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 't']] 0.000
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'ct']] 0.006
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'n']] 0.000
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'c']] 0.000
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 't']] 0.008
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'ct']] 0.000
# done
# [(1, 1, 0), (0, 0, 0, 0), 'c'] 0.0
# [(1, 1, 1), (0, 0, 0, 0), 'n'] 0.0
# [(2, 1, 1), (0, 0, 0, 0), 'c'] 0.0

# %% [markdown]
# ## 13.3 Case Study 1: No Trend or Seasonality

# %%
import pandas as pd

# %%
series_fem_births = pd.read_csv('../data_and_models/daily-total-female-births.csv', header=0, index_col=0)
data = series_fem_births.values

# %%
series_fem_births
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
series_fem_births['Births']
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
#               ..
# 1959-12-27    37
# 1959-12-28    52
# 1959-12-29    48
# 1959-12-30    55
# 1959-12-31    50
# Name: Births, Length: 365, dtype: int64

# %%
type(series_fem_births)
# Out:
# pandas.core.frame.DataFrame

# %%
type(series_fem_births['Births'])
# Out:
# pandas.core.series.Series

# %%
type(series_fem_births['Births'].values)
# Out:
# numpy.ndarray

# %%
series_fem_births['Births'].values
# Out:
# array([35, 32, 30, 31, 44, 29, 45, 43, 38, 27, 38, 33, 55, 47, 45, 37, 50,
#        43, 41, 52, 34, 53, 39, 32, 37, 43, 39, 35, 44, 38, 24, 23, 31, 44,
#        38, 50, 38, 51, 31, 31, 51, 36, 45, 51, 34, 52, 47, 45, 46, 39, 48,
#        37, 35, 52, 42, 45, 39, 37, 30, 35, 28, 45, 34, 36, 50, 44, 39, 32,
#        39, 45, 43, 39, 31, 27, 30, 42, 46, 41, 36, 45, 46, 43, 38, 34, 35,
#        56, 36, 32, 50, 41, 39, 41, 47, 34, 36, 33, 35, 38, 38, 34, 53, 34,
#        34, 38, 35, 32, 42, 34, 46, 30, 46, 45, 54, 34, 37, 35, 40, 42, 58,
#        51, 32, 35, 38, 33, 39, 47, 38, 52, 30, 34, 40, 35, 42, 41, 42, 38,
#        24, 34, 43, 36, 55, 41, 45, 41, 37, 43, 39, 33, 43, 40, 38, 45, 46,
#        34, 35, 48, 51, 36, 33, 46, 42, 48, 34, 41, 35, 40, 34, 30, 36, 40,
#        39, 45, 38, 47, 33, 30, 42, 43, 41, 41, 59, 43, 45, 38, 37, 45, 42,
#        57, 46, 51, 41, 47, 26, 35, 44, 41, 42, 36, 45, 45, 45, 47, 38, 42,
#        35, 36, 39, 45, 43, 47, 36, 41, 50, 39, 41, 46, 64, 45, 34, 38, 44,
#        48, 46, 44, 37, 39, 44, 45, 33, 44, 38, 46, 46, 40, 39, 44, 48, 50,
#        41, 42, 51, 41, 44, 38, 68, 40, 42, 51, 44, 45, 36, 57, 44, 42, 53,
#        42, 34, 40, 56, 44, 53, 55, 39, 59, 55, 73, 55, 44, 43, 40, 47, 51,
#        56, 49, 54, 56, 47, 44, 43, 42, 45, 50, 48, 43, 40, 59, 41, 42, 51,
#        49, 45, 43, 42, 38, 47, 38, 36, 42, 35, 28, 44, 36, 45, 46, 48, 49,
#        43, 42, 59, 45, 52, 46, 42, 40, 40, 45, 35, 35, 40, 39, 33, 42, 47,
#        51, 44, 40, 57, 49, 45, 49, 51, 46, 44, 52, 45, 32, 46, 41, 34, 33,
#        36, 49, 43, 43, 34, 39, 35, 52, 47, 52, 39, 40, 42, 42, 53, 39, 40,
#        38, 44, 34, 37, 52, 48, 55, 50])

# %%
# data split
n_test = 165

# model configs
cfg_list = sarima_configs()

# %%
len(cfg_list)
# Out:
# 1296

# %%
# %%time
# grid search
scores = grid_search(data, cfg_list, n_test)
print('done')
# Out:
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'n']] 44.930
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'c']] 7.718
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 't']] 20.364
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'n']] 26.223
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'ct']] 7.195
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'c']] 7.450
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 't']] 14.095
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'n']] 19.048
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'c']] 7.364
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'n']] 8.722
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'c']] 8.738
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'ct']] 7.068
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 't']] 8.770
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'ct']] 8.787
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 't']] 11.748
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'n']] 7.080
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'c']] 7.115
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'ct']] 7.050
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'n']] 7.014
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 't']] 7.156
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'c']] 7.042
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'n']] 8.708
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'ct']] 7.118
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'c']] 7.383
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 't']] 8.581
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 't']] 7.059
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'ct']] 7.037
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'ct']] 7.088
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'n']] 7.114
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'c']] 7.346
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 't']] 7.166
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'ct']] 7.018
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'n']] 7.046
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'n']] 7.887
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'c']] 7.902
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 't']] 7.931
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'ct']] 7.042
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'ct']] 7.946
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'n']] 7.001
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 't']] 7.038
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'c']] 7.037
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'c']] 7.372
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'n']] 7.023
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 't']] 7.099
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'c']] 7.077
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'n']] 7.893
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'c']] 7.299
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'ct']] 7.113
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 't']] 7.868
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'ct']] 7.025
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 't']] 7.090
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'n']] 7.027
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'ct']] 7.116
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'c']] 7.360
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'ct']] 7.027
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 't']] 7.240
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'n']] 7.080
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'n']] 7.519
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'c']] 7.533
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 't']] 7.561
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'ct']] 7.576
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'ct']] 7.044
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'c']] 7.530
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 't']] 7.096
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'n']] 7.007
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'c']] 7.039
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 'n']] 6.999
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 't']] 7.149
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 'c']] 7.043
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'ct']] 7.073
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 't']] 7.078
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 'ct']] 7.109
# done
# CPU times: user 721 ms, sys: 231 ms, total: 952 ms
# Wall time: 14min 9s

# %%
# list top 3 configs
for cfg, error in scores[:3]:
    print(cfg, error)
# Out:
# [(2, 1, 2), (0, 0, 0, 0), 'n'] 6.999160722366063
# [(1, 1, 1), (0, 0, 0, 0), 'n'] 7.001420328402211
# [(2, 1, 1), (0, 0, 0, 0), 'n'] 7.006522229630941

# %% [markdown]
# ## 13.4 Case Study 2: Trend
# The monthly shampoo sales dataset summarizes the monthly sales of shampoo over a three-year
# period. For more information on this dataset, see Chapter 11 where it was introduced. You can
# download the dataset directly from here:

# %%
# load dataset
series = pd.read_csv('../data_and_models/monthly-shampoo-sales.csv', header=0, index_col=0)
data = series.values

# data split
n_test = 12

# model configs
cfg_list = sarima_configs()
len(cfg_list)
# Out:
# 1296

# %%
cfg_list[:10]
# Out:
# [[(0, 0, 0), (0, 0, 0, 0), 'n'],
#  [(0, 0, 0), (0, 0, 1, 0), 'n'],
#  [(0, 0, 0), (0, 0, 2, 0), 'n'],
#  [(0, 0, 0), (0, 1, 0, 0), 'n'],
#  [(0, 0, 0), (0, 1, 1, 0), 'n'],
#  [(0, 0, 0), (0, 1, 2, 0), 'n'],
#  [(0, 0, 0), (1, 0, 0, 0), 'n'],
#  [(0, 0, 0), (1, 0, 1, 0), 'n'],
#  [(0, 0, 0), (1, 0, 2, 0), 'n'],
#  [(0, 0, 0), (1, 1, 0, 0), 'n']]

# %%
# %%time 
x = 1
# Out:
# CPU times: user 7 µs, sys: 2 µs, total: 9 µs
# Wall time: 16 µs

# %%
# %%time
# grid search
scores = grid_search(data, cfg_list, n_test)
print('done')
# Out:
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'n']] 491.532
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'c']] 235.880
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 't']] 81.900
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'ct']] 103.880
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'n']] 328.076
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 't']] 87.885
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'c']] 198.046
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'ct']] 104.414
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'n']] 264.173
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'n']] 136.761
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'c']] 137.368
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'c']] 158.296
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 't']] 76.317
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 't']] 141.006
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'ct']] 143.827
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'n']] 107.044
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'ct']] 92.340
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'c']] 101.681
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 't']] 81.041
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'n']] 67.398
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'ct']] 84.086
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'n']] 144.299
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'c']] 154.445
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'c']] 65.846
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 't']] 72.886
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 't']] 98.845
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'ct']] 106.448
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'ct']] 67.888
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'n']] 84.467
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'c']] 91.474
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 't']] 80.087
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'n']] 75.366
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'ct']] 103.477
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'n']] 92.107
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'c']] 86.977
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 't']] 85.288
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'ct']] 86.514
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'c']] 75.036
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'ct']] 92.257
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'n']] 91.909
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 't']] 60.664
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 't']] 64.100
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'c']] 83.829
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'n']] 82.123
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'ct']] 61.646
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'n']] 88.757
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'c']] 82.394
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 't']] 67.802
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'c']] 98.030
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 't']] 77.384
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'ct']] 68.869
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'n']] 72.974
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'ct']] 91.399
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'c']] 71.918
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'n']] 74.027
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 't']] 62.164
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'ct']] 87.987
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'n']] 88.226
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'c']] 76.518
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 't']] 71.260
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'c']] 72.541
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 't']] 66.156
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'ct']] 72.637
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'ct']] 95.639
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'n']] 91.804
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'c']] 83.592
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 't']] 65.253
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 'n']] 89.614
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'ct']] 61.799
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 'c']] 86.907
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 't']] 65.568
#  > Model[[(2, 1, 2), (0, 0, 0, 0), 'ct']] 61.517
# done
# CPU times: user 192 ms, sys: 78.2 ms, total: 270 ms
# Wall time: 21.3 s

# %%
# list top 3 configs
for cfg, error in scores[:3]:
    print(cfg, error)
# Out:
# [(1, 0, 2), (0, 0, 0, 0), 't'] 60.66374837873062
# [(2, 1, 2), (0, 0, 0, 0), 'ct'] 61.51703872378202
# [(1, 1, 1), (0, 0, 0, 0), 'ct'] 61.645696055223

# %% [markdown]
# ## 13.6 Case Study 4: Trend and Seasonality

# %%
series = pd.read_csv('../data_and_models/monthly-car-sales.csv', header=0, index_col=0)
data = series.values

# data split
n_test = 12

# model configs
cfg_list = sarima_configs(seasonal=[0,6,12])

# %%
len(cfg_list)
# Out:
# 3888

# %%
cfg_list[:20]
# Out:
# [[(0, 0, 0), (0, 0, 0, 0), 'n'],
#  [(0, 0, 0), (0, 0, 0, 6), 'n'],
#  [(0, 0, 0), (0, 0, 0, 12), 'n'],
#  [(0, 0, 0), (0, 0, 1, 0), 'n'],
#  [(0, 0, 0), (0, 0, 1, 6), 'n'],
#  [(0, 0, 0), (0, 0, 1, 12), 'n'],
#  [(0, 0, 0), (0, 0, 2, 0), 'n'],
#  [(0, 0, 0), (0, 0, 2, 6), 'n'],
#  [(0, 0, 0), (0, 0, 2, 12), 'n'],
#  [(0, 0, 0), (0, 1, 0, 0), 'n'],
#  [(0, 0, 0), (0, 1, 0, 6), 'n'],
#  [(0, 0, 0), (0, 1, 0, 12), 'n'],
#  [(0, 0, 0), (0, 1, 1, 0), 'n'],
#  [(0, 0, 0), (0, 1, 1, 6), 'n'],
#  [(0, 0, 0), (0, 1, 1, 12), 'n'],
#  [(0, 0, 0), (0, 1, 2, 0), 'n'],
#  [(0, 0, 0), (0, 1, 2, 6), 'n'],
#  [(0, 0, 0), (0, 1, 2, 12), 'n'],
#  [(0, 0, 0), (1, 0, 0, 0), 'n'],
#  [(0, 0, 0), (1, 0, 0, 6), 'n']]

# %%
# %%time
# grid search
scores = grid_search(data, cfg_list, n_test)
print('done')
# Out:
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'n']] 18608.652
#  > Model[[(0, 0, 0), (0, 0, 0, 12), 'n']] 18608.652
#  > Model[[(0, 0, 0), (0, 0, 0, 6), 'n']] 18608.652
#  > Model[[(0, 0, 0), (0, 0, 1, 6), 'n']] 13642.801
#  > Model[[(0, 0, 0), (0, 1, 0, 6), 'n']] 5798.153
#  > Model[[(0, 0, 0), (0, 0, 1, 12), 'n']] 11897.521
#  > Model[[(0, 0, 0), (0, 1, 0, 12), 'n']] 2290.827
#  > Model[[(0, 0, 0), (0, 0, 2, 6), 'n']] 8191.126
#  > Model[[(0, 0, 0), (0, 1, 1, 6), 'n']] 3958.654
#  > Model[[(0, 0, 0), (0, 1, 1, 12), 'n']] 2286.289
#  > Model[[(0, 0, 0), (1, 0, 0, 6), 'n']] 5951.270
#  > Model[[(0, 0, 0), (1, 0, 0, 12), 'n']] 1850.671
#  > Model[[(0, 0, 0), (1, 0, 1, 6), 'n']] 3764.214
#  > Model[[(0, 0, 0), (1, 0, 2, 6), 'n']] 3108.363
#  > Model[[(0, 0, 0), (0, 1, 2, 6), 'n']] 3044.365
#  > Model[[(0, 0, 0), (1, 0, 1, 12), 'n']] 1771.231
#  > Model[[(0, 0, 0), (1, 1, 0, 6), 'n']] 2242.874
#  > Model[[(0, 0, 0), (1, 1, 0, 12), 'n']] 2284.034
#  > Model[[(0, 0, 0), (0, 0, 2, 12), 'n']] 9177.881
#  > Model[[(0, 0, 0), (1, 1, 1, 6), 'n']] 2131.148
#  > Model[[(0, 0, 0), (1, 1, 2, 6), 'n']] 2150.004
#  > Model[[(0, 0, 0), (1, 0, 2, 12), 'n']] 2444.456
#  > Model[[(0, 0, 0), (1, 1, 1, 12), 'n']] 2063.108
#  > Model[[(0, 0, 0), (2, 0, 0, 6), 'n']] 1744.718
#  > Model[[(0, 0, 0), (2, 0, 0, 12), 'n']] 1642.082
#  > Model[[(0, 0, 0), (2, 0, 1, 6), 'n']] 1745.608
#  > Model[[(0, 0, 0), (2, 0, 2, 6), 'n']] 1695.725
#  > Model[[(0, 0, 0), (2, 0, 1, 12), 'n']] 1712.929
#  > Model[[(0, 0, 0), (2, 1, 0, 6), 'n']] 2148.423
#  > Model[[(0, 0, 0), (2, 1, 0, 12), 'n']] 2403.725
#  > Model[[(0, 0, 0), (2, 1, 1, 6), 'n']] 2161.693
#  > Model[[(0, 0, 0), (0, 1, 2, 12), 'n']] 1141576779.879
#  > Model[[(0, 0, 0), (2, 0, 2, 12), 'n']] 2313.378
#  > Model[[(0, 0, 0), (2, 1, 1, 12), 'n']] 1890.475
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'c']] 5399.238
#  > Model[[(0, 0, 0), (0, 0, 0, 6), 'c']] 5399.238
#  > Model[[(0, 0, 0), (0, 0, 0, 12), 'c']] 5399.238
#  > Model[[(0, 0, 0), (0, 0, 1, 6), 'c']] 5288.823
#  > Model[[(0, 0, 0), (0, 0, 1, 12), 'c']] 3476.060
#  > Model[[(0, 0, 0), (2, 1, 2, 6), 'n']] 1892.634
#  > Model[[(0, 0, 0), (0, 0, 2, 6), 'c']] 3005.463
#  > Model[[(0, 0, 0), (0, 1, 0, 6), 'c']] 5781.307
#  > Model[[(0, 0, 0), (0, 1, 0, 12), 'c']] 1743.503
#  > Model[[(0, 0, 0), (0, 1, 1, 6), 'c']] 3744.866
#  > Model[[(0, 0, 0), (0, 1, 1, 12), 'c']] 1581.692
#  > Model[[(0, 0, 0), (0, 0, 2, 12), 'c']] 3982.120
#  > Model[[(0, 0, 0), (0, 1, 2, 6), 'c']] 2611.709
#  > Model[[(0, 0, 0), (1, 0, 0, 6), 'c']] 5017.829
#  > Model[[(0, 0, 0), (1, 0, 0, 12), 'c']] 1778.320
#  > Model[[(0, 0, 0), (1, 1, 2, 12), 'n']] 26732721215.859
#  > Model[[(0, 0, 0), (1, 0, 1, 6), 'c']] 5097.859
#  > Model[[(0, 0, 0), (1, 0, 1, 12), 'c']] 2563.359
#  > Model[[(0, 0, 0), (1, 0, 2, 6), 'c']] 3016.119
#  > Model[[(0, 0, 0), (1, 1, 0, 6), 'c']] 1803.545
#  > Model[[(0, 0, 0), (1, 1, 0, 12), 'c']] 1559.338
#  > Model[[(0, 0, 0), (1, 1, 1, 6), 'c']] 1845.414
#  > Model[[(0, 0, 0), (1, 0, 2, 12), 'c']] 2790.445
#  > Model[[(0, 0, 0), (1, 1, 1, 12), 'c']] 1744.499
#  > Model[[(0, 0, 0), (2, 1, 2, 12), 'n']] 341199699.774
#  > Model[[(0, 0, 0), (1, 1, 2, 6), 'c']] 1660.718
#  > Model[[(0, 0, 0), (2, 0, 0, 6), 'c']] 2336.917
#  > Model[[(0, 0, 0), (2, 0, 1, 6), 'c']] 2689.777
#  > Model[[(0, 0, 0), (2, 0, 0, 12), 'c']] 3273.821
#  > Model[[(0, 0, 0), (2, 0, 1, 12), 'c']] 2399.779
#  > Model[[(0, 0, 0), (0, 1, 2, 12), 'c']] 112104245.162
#  > Model[[(0, 0, 0), (2, 0, 2, 6), 'c']] 2545.837
#  > Model[[(0, 0, 0), (2, 1, 0, 6), 'c']] 1766.510
#  > Model[[(0, 0, 0), (2, 1, 0, 12), 'c']] 1618.722
#  > Model[[(0, 0, 0), (2, 1, 1, 6), 'c']] 1519.243
#  > Model[[(0, 0, 0), (2, 0, 2, 12), 'c']] 3696.819
#  > Model[[(0, 0, 0), (2, 1, 1, 12), 'c']] 1557.335
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 't']] 6760.052
#  > Model[[(0, 0, 0), (0, 0, 0, 6), 't']] 6760.052
#  > Model[[(0, 0, 0), (0, 0, 0, 12), 't']] 6760.052
#  > Model[[(0, 0, 0), (0, 0, 1, 6), 't']] 6067.089
#  > Model[[(0, 0, 0), (0, 0, 1, 12), 't']] 3450.779
#  > Model[[(0, 0, 0), (0, 0, 2, 6), 't']] 3456.878
#  > Model[[(0, 0, 0), (2, 1, 2, 6), 'c']] 1857.280
#  > Model[[(0, 0, 0), (0, 1, 0, 6), 't']] 5841.119
#  > Model[[(0, 0, 0), (0, 1, 0, 12), 't']] 1667.756
#  > Model[[(0, 0, 0), (0, 1, 1, 6), 't']] 3727.753
#  > Model[[(0, 0, 0), (0, 1, 1, 12), 't']] 1602.632
#  > Model[[(0, 0, 0), (1, 1, 2, 12), 'c']] 19828431053.697
#  > Model[[(0, 0, 0), (0, 0, 2, 12), 't']] 3254.804
#  > Model[[(0, 0, 0), (0, 1, 2, 6), 't']] 2748.307
#  > Model[[(0, 0, 0), (1, 0, 0, 6), 't']] 5127.191
#  > Model[[(0, 0, 0), (1, 0, 1, 6), 't']] 4046.048
#  > Model[[(0, 0, 0), (1, 0, 0, 12), 't']] 1898.769
#  > Model[[(0, 0, 0), (1, 0, 1, 12), 't']] 2028.589
#  > Model[[(0, 0, 0), (1, 0, 2, 6), 't']] 2553.985
#  > Model[[(0, 0, 0), (1, 1, 0, 6), 't']] 1638.344
#  > Model[[(0, 0, 0), (1, 1, 0, 12), 't']] 1551.842
#  > Model[[(0, 0, 0), (1, 1, 1, 6), 't']] 1716.245
#  > Model[[(0, 0, 0), (1, 0, 2, 12), 't']] 3079.832
#  > Model[[(0, 0, 0), (1, 1, 1, 12), 't']] 1601.331
#  > Model[[(0, 0, 0), (2, 1, 2, 12), 'c']] 5114866445.459
#  > Model[[(0, 0, 0), (0, 1, 2, 12), 't']] 832213450.424
#  > Model[[(0, 0, 0), (1, 1, 2, 6), 't']] 1854.768
#  > Model[[(0, 0, 0), (2, 0, 0, 6), 't']] 2050.618
#  > Model[[(0, 0, 0), (2, 0, 1, 6), 't']] 2600.407
#  > Model[[(0, 0, 0), (2, 0, 0, 12), 't']] 1813.797
#  > Model[[(0, 0, 0), (2, 0, 1, 12), 't']] 2297.148
#  > Model[[(0, 0, 0), (2, 0, 2, 6), 't']] 2199.192
#  > Model[[(0, 0, 0), (2, 1, 0, 6), 't']] 1626.997
#  > Model[[(0, 0, 0), (2, 1, 0, 12), 't']] 1632.527
#  > Model[[(0, 0, 0), (2, 0, 2, 12), 't']] 3255.584
#  > Model[[(0, 0, 0), (2, 1, 1, 6), 't']] 2668.048
#  > Model[[(0, 0, 0), (2, 1, 2, 6), 't']] 2367.149
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'ct']] 3867.394
#  > Model[[(0, 0, 0), (0, 0, 0, 6), 'ct']] 3867.394
#  > Model[[(0, 0, 0), (0, 0, 0, 12), 'ct']] 3867.394
#  > Model[[(0, 0, 0), (1, 1, 2, 12), 't']] 24482187333.820
#  > Model[[(0, 0, 0), (0, 0, 1, 6), 'ct']] 3877.946
#  > Model[[(0, 0, 0), (0, 0, 1, 12), 'ct']] 2210.276
#  > Model[[(0, 0, 0), (2, 1, 1, 12), 't']] 1876.803
#  > Model[[(0, 0, 0), (0, 1, 0, 6), 'ct']] 5901.684
#  > Model[[(0, 0, 0), (0, 1, 0, 12), 'ct']] 2042.261
#  > Model[[(0, 0, 0), (0, 0, 2, 6), 'ct']] 2399.496
#  > Model[[(0, 0, 0), (0, 1, 1, 6), 'ct']] 3744.647
#  > Model[[(0, 0, 0), (0, 1, 1, 12), 'ct']] 1902.115
#  > Model[[(0, 0, 0), (0, 1, 2, 6), 'ct']] 2653.336
#  > Model[[(0, 0, 0), (0, 0, 2, 12), 'ct']] 2288.625
#  > Model[[(0, 0, 0), (1, 0, 0, 6), 'ct']] 3951.130
#  > Model[[(0, 0, 0), (1, 0, 1, 6), 'ct']] 3980.475
#  > Model[[(0, 0, 0), (1, 0, 0, 12), 'ct']] 3071.773
#  > Model[[(0, 0, 0), (1, 0, 1, 12), 'ct']] 2315.468
#  > Model[[(0, 0, 0), (1, 0, 2, 6), 'ct']] 2492.027
#  > Model[[(0, 0, 0), (1, 1, 0, 6), 'ct']] 1837.020
#  > Model[[(0, 0, 0), (1, 1, 0, 12), 'ct']] 2058.305
#  > Model[[(0, 0, 0), (1, 0, 2, 12), 'ct']] 5299.937
#  > Model[[(0, 0, 0), (1, 1, 1, 6), 'ct']] 1702.634
#  > Model[[(0, 0, 0), (0, 1, 2, 12), 'ct']] 415827053.368
#  > Model[[(0, 0, 0), (2, 1, 2, 12), 't']] 20138277.233
#  > Model[[(0, 0, 0), (1, 1, 1, 12), 'ct']] 1975.630
#  > Model[[(0, 0, 0), (2, 0, 0, 6), 'ct']] 2463.871
#  > Model[[(0, 0, 0), (1, 1, 2, 6), 'ct']] 2197.264
#  > Model[[(0, 0, 0), (2, 0, 1, 6), 'ct']] 2012.759
#  > Model[[(0, 0, 0), (2, 0, 0, 12), 'ct']] 3261.404
#  > Model[[(0, 0, 0), (2, 0, 2, 6), 'ct']] 2180.562
#  > Model[[(0, 0, 0), (2, 0, 1, 12), 'ct']] 2927.286
#  > Model[[(0, 0, 0), (2, 1, 0, 6), 'ct']] 1670.820
#  > Model[[(0, 0, 0), (2, 0, 2, 12), 'ct']] 4061.067
#  > Model[[(0, 0, 0), (2, 1, 1, 6), 'ct']] 2344.569
#  > Model[[(0, 0, 0), (2, 1, 0, 12), 'ct']] 1730.816
#  > Model[[(0, 0, 0), (2, 1, 1, 12), 'ct']] 1979.076
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'n']] 9928.438
#  > Model[[(0, 0, 1), (0, 0, 0, 6), 'n']] 9928.438
#  > Model[[(0, 0, 0), (2, 1, 2, 6), 'ct']] 2030.862
#  > Model[[(0, 0, 1), (0, 0, 0, 12), 'n']] 9928.438
#  > Model[[(0, 0, 1), (0, 0, 1, 6), 'n']] 8179.695
#  > Model[[(0, 0, 1), (0, 0, 1, 12), 'n']] 6249.212
#  > Model[[(0, 0, 1), (0, 0, 2, 6), 'n']] 5659.620
#  > Model[[(0, 0, 0), (1, 1, 2, 12), 'ct']] 18172886366.888
#  > Model[[(0, 0, 1), (0, 1, 0, 6), 'n']] 5129.087
#  > Model[[(0, 0, 1), (0, 1, 0, 12), 'n']] 2213.436
#  > Model[[(0, 0, 1), (0, 1, 1, 6), 'n']] 3568.356
#  > Model[[(0, 0, 1), (0, 1, 1, 12), 'n']] 2177.869
#  > Model[[(0, 0, 1), (0, 1, 2, 6), 'n']] 2922.576
#  > Model[[(0, 0, 1), (0, 0, 2, 12), 'n']] 48413.629
#  > Model[[(0, 0, 1), (1, 0, 0, 6), 'n']] 5216.183
#  > Model[[(0, 0, 1), (1, 0, 0, 12), 'n']] 1927.626
#  > Model[[(0, 0, 1), (1, 0, 1, 6), 'n']] 3475.762
#  > Model[[(0, 0, 1), (1, 0, 1, 12), 'n']] 1857.964
#  > Model[[(0, 0, 1), (1, 0, 2, 6), 'n']] 2907.726
#  > Model[[(0, 0, 1), (1, 1, 0, 6), 'n']] 2163.544
#  > Model[[(0, 0, 1), (1, 1, 0, 12), 'n']] 2157.205
#  > Model[[(0, 0, 1), (1, 1, 1, 6), 'n']] 2121.627
#  > Model[[(0, 0, 1), (1, 1, 1, 12), 'n']] 2154.609
#  > Model[[(0, 0, 1), (1, 0, 2, 12), 'n']] 14018684510.528
#  > Model[[(0, 0, 1), (1, 1, 2, 6), 'n']] 2142.492
#  > Model[[(0, 0, 1), (0, 1, 2, 12), 'n']] 1402950496.845
#  > Model[[(0, 0, 1), (2, 0, 0, 6), 'n']] 1828.992
#  > Model[[(0, 0, 0), (2, 1, 2, 12), 'ct']] 637495245.739
#  > Model[[(0, 0, 1), (2, 0, 0, 12), 'n']] 1827.069
#  > Model[[(0, 0, 1), (2, 0, 1, 6), 'n']] 1864.846
#  > Model[[(0, 0, 1), (2, 0, 2, 6), 'n']] 2924.587
#  > Model[[(0, 0, 1), (2, 0, 1, 12), 'n']] 1893.437
#  > Model[[(0, 0, 1), (2, 1, 0, 6), 'n']] 2096.306
#  > Model[[(0, 0, 1), (2, 0, 2, 12), 'n']] 90373312.317
#  > Model[[(0, 0, 1), (2, 1, 0, 12), 'n']] 2276.362
#  > Model[[(0, 0, 1), (2, 1, 1, 6), 'n']] 2172.884
#  > Model[[(0, 0, 1), (2, 1, 2, 6), 'n']] 2059.129
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'c']] 4076.477
#  > Model[[(0, 0, 1), (1, 1, 2, 12), 'n']] 21932201026.124
#  > Model[[(0, 0, 1), (0, 0, 0, 6), 'c']] 4076.477
#  > Model[[(0, 0, 1), (0, 0, 0, 12), 'c']] 4076.477
#  > Model[[(0, 0, 1), (0, 0, 1, 6), 'c']] 4091.969
#  > Model[[(0, 0, 1), (2, 1, 1, 12), 'n']] 1924.673
#  > Model[[(0, 0, 1), (0, 0, 1, 12), 'c']] 2801.456
#  > Model[[(0, 0, 1), (0, 1, 0, 6), 'c']] 5135.020
#  > Model[[(0, 0, 1), (0, 1, 0, 12), 'c']] 1823.166
#  > Model[[(0, 0, 1), (0, 0, 2, 6), 'c']] 2385.493
#  > Model[[(0, 0, 1), (0, 1, 1, 12), 'c']] 1700.664
#  > Model[[(0, 0, 1), (0, 1, 1, 6), 'c']] 3283.701
#  > Model[[(0, 0, 1), (0, 1, 2, 6), 'c']] 2603.324
#  > Model[[(0, 0, 1), (1, 0, 0, 6), 'c']] 3991.255
#  > Model[[(0, 0, 1), (1, 0, 0, 12), 'c']] 3317.750
#  > Model[[(0, 0, 1), (0, 0, 2, 12), 'c']] 5800.990
#  > Model[[(0, 0, 1), (1, 0, 1, 6), 'c']] 3940.027
#  > Model[[(0, 0, 1), (1, 0, 1, 12), 'c']] 2290.421
#  > Model[[(0, 0, 1), (1, 0, 2, 6), 'c']] 2426.319
#  > Model[[(0, 0, 1), (1, 1, 0, 6), 'c']] 1878.030
#  > Model[[(0, 0, 1), (1, 1, 0, 12), 'c']] 1681.946
#  > Model[[(0, 0, 1), (1, 0, 2, 12), 'c']] 5848.274
#  > Model[[(0, 0, 1), (1, 1, 1, 6), 'c']] 1997.387
#  > Model[[(0, 0, 1), (1, 1, 1, 12), 'c']] 1815.503
#  > Model[[(0, 0, 1), (2, 1, 2, 12), 'n']] 12963270.112
#  > Model[[(0, 0, 1), (0, 1, 2, 12), 'c']] 252387076.269
#  > Model[[(0, 0, 1), (1, 1, 2, 6), 'c']] 1926.022
#  > Model[[(0, 0, 1), (2, 0, 0, 6), 'c']] 2664.115
#  > Model[[(0, 0, 1), (2, 0, 1, 6), 'c']] 2351.200
#  > Model[[(0, 0, 1), (2, 0, 0, 12), 'c']] 3114.636
#  > Model[[(0, 0, 1), (2, 0, 1, 12), 'c']] 2187.736
#  > Model[[(0, 0, 1), (2, 0, 2, 6), 'c']] 2361.163
#  > Model[[(0, 0, 1), (2, 1, 0, 6), 'c']] 1833.024
#  > Model[[(0, 0, 1), (2, 1, 0, 12), 'c']] 1718.999
#  > Model[[(0, 0, 1), (2, 0, 2, 12), 'c']] 3075.147
#  > Model[[(0, 0, 1), (2, 1, 1, 6), 'c']] 1774.668
#  > Model[[(0, 0, 1), (2, 1, 1, 12), 'c']] 1693.289
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 't']] 4608.453
#  > Model[[(0, 0, 1), (0, 0, 0, 6), 't']] 4608.453
#  > Model[[(0, 0, 1), (0, 0, 0, 12), 't']] 4608.453
#  > Model[[(0, 0, 1), (0, 0, 1, 6), 't']] 4494.396
#  > Model[[(0, 0, 1), (2, 1, 2, 6), 'c']] 1896.282
#  > Model[[(0, 0, 1), (1, 1, 2, 12), 'c']] 4177773528.569
#  > Model[[(0, 0, 1), (0, 0, 1, 12), 't']] 2734.431
#  > Model[[(0, 0, 1), (0, 1, 0, 6), 't']] 5186.615
#  > Model[[(0, 0, 1), (0, 1, 0, 12), 't']] 1789.164
#  > Model[[(0, 0, 1), (0, 0, 2, 6), 't']] 2488.302
#  > Model[[(0, 0, 1), (0, 1, 1, 6), 't']] 3440.497
#  > Model[[(0, 0, 1), (0, 1, 1, 12), 't']] 1735.274
#  > Model[[(0, 0, 1), (0, 0, 2, 12), 't']] 16839.053
#  > Model[[(0, 0, 1), (0, 1, 2, 6), 't']] 2771.751
#  > Model[[(0, 0, 1), (1, 0, 0, 6), 't']] 4347.809
#  > Model[[(0, 0, 1), (1, 0, 0, 12), 't']] 1961.172
#  > Model[[(0, 0, 1), (1, 0, 1, 6), 't']] 3471.198
#  > Model[[(0, 0, 1), (1, 0, 1, 12), 't']] 3089.070
#  > Model[[(0, 0, 1), (1, 0, 2, 6), 't']] 2728.911
#  > Model[[(0, 0, 1), (1, 1, 0, 6), 't']] 1758.201
#  > Model[[(0, 0, 1), (1, 1, 0, 12), 't']] 1752.255
#  > Model[[(0, 0, 1), (1, 0, 2, 12), 't']] 2399.233
#  > Model[[(0, 0, 1), (1, 1, 1, 6), 't']] 1945.280
#  > Model[[(0, 0, 1), (0, 1, 2, 12), 't']] 1178514690.600
#  > Model[[(0, 0, 1), (1, 1, 1, 12), 't']] 1766.638
#  > Model[[(0, 0, 1), (2, 1, 2, 12), 'c']] 92254192.355
#  > Model[[(0, 0, 1), (1, 1, 2, 6), 't']] 2338.535
#  > Model[[(0, 0, 1), (2, 0, 0, 6), 't']] 2373.921
#  > Model[[(0, 0, 1), (2, 0, 1, 6), 't']] 2112.297
#  > Model[[(0, 0, 1), (2, 0, 0, 12), 't']] 2502.984
#  > Model[[(0, 0, 1), (2, 0, 2, 6), 't']] 2663.543
#  > Model[[(0, 0, 1), (2, 0, 1, 12), 't']] 1962.096
#  > Model[[(0, 0, 1), (2, 1, 0, 6), 't']] 1734.510
#  > Model[[(0, 0, 1), (2, 0, 2, 12), 't']] 2600.406
#  > Model[[(0, 0, 1), (2, 1, 0, 12), 't']] 1748.944
#  > Model[[(0, 0, 1), (2, 1, 1, 6), 't']] 2220.990
#  > Model[[(0, 0, 1), (1, 1, 2, 12), 't']] 67837908131.340
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'ct']] 3364.611
#  > Model[[(0, 0, 1), (2, 1, 2, 6), 't']] 2431.234
#  > Model[[(0, 0, 1), (0, 0, 0, 6), 'ct']] 3364.611
#  > Model[[(0, 0, 1), (0, 0, 0, 12), 'ct']] 3364.611
#  > Model[[(0, 0, 1), (0, 0, 1, 6), 'ct']] 3330.787
#  > Model[[(0, 0, 1), (0, 0, 1, 12), 'ct']] 2103.413
#  > Model[[(0, 0, 1), (0, 0, 2, 6), 'ct']] 2034.240
#  > Model[[(0, 0, 1), (0, 1, 0, 6), 'ct']] 5250.819
#  > Model[[(0, 0, 1), (2, 1, 1, 12), 't']] 2088.396
#  > Model[[(0, 0, 1), (0, 1, 0, 12), 'ct']] 2020.524
#  > Model[[(0, 0, 1), (0, 1, 1, 6), 'ct']] 3348.345
#  > Model[[(0, 0, 1), (0, 1, 1, 12), 'ct']] 1795.056
#  > Model[[(0, 0, 1), (0, 0, 2, 12), 'ct']] 2731.735
#  > Model[[(0, 0, 1), (1, 0, 0, 6), 'ct']] 3436.297
#  > Model[[(0, 0, 1), (0, 1, 2, 6), 'ct']] 2782.356
#  > Model[[(0, 0, 1), (1, 0, 1, 6), 'ct']] 3412.130
#  > Model[[(0, 0, 1), (1, 0, 0, 12), 'ct']] 2826.633
#  > Model[[(0, 0, 1), (1, 0, 1, 12), 'ct']] 2225.422
#  > Model[[(0, 0, 1), (1, 0, 2, 6), 'ct']] 2362.285
#  > Model[[(0, 0, 1), (1, 1, 0, 6), 'ct']] 1797.564
#  > Model[[(0, 0, 1), (1, 1, 0, 12), 'ct']] 1834.982
#  > Model[[(0, 0, 1), (2, 1, 2, 12), 't']] 13159887.496
#  > Model[[(0, 0, 1), (1, 0, 2, 12), 'ct']] 6132.108
#  > Model[[(0, 0, 1), (1, 1, 1, 6), 'ct']] 1966.082
#  > Model[[(0, 0, 1), (1, 1, 1, 12), 'ct']] 1929.666
#  > Model[[(0, 0, 1), (0, 1, 2, 12), 'ct']] 1234065470.928
#  > Model[[(0, 0, 1), (2, 0, 0, 6), 'ct']] 2227.746
#  > Model[[(0, 0, 1), (1, 1, 2, 6), 'ct']] 2350.763
#  > Model[[(0, 0, 1), (2, 0, 1, 6), 'ct']] 2277.497
#  > Model[[(0, 0, 1), (2, 0, 0, 12), 'ct']] 3220.590
#  > Model[[(0, 0, 1), (2, 0, 2, 6), 'ct']] 2252.784
#  > Model[[(0, 0, 1), (2, 0, 1, 12), 'ct']] 2428.273
#  > Model[[(0, 0, 1), (2, 1, 0, 6), 'ct']] 1911.032
#  > Model[[(0, 0, 1), (2, 0, 2, 12), 'ct']] 3269.528
#  > Model[[(0, 0, 1), (2, 1, 0, 12), 'ct']] 1736.286
#  > Model[[(0, 0, 1), (1, 1, 2, 12), 'ct']] 15352372620.824
#  > Model[[(0, 0, 1), (2, 1, 1, 6), 'ct']] 2070.304
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'n']] 7278.585
#  > Model[[(0, 0, 2), (0, 0, 0, 6), 'n']] 7278.585
#  > Model[[(0, 0, 2), (0, 0, 0, 12), 'n']] 7278.585
#  > Model[[(0, 0, 2), (0, 0, 1, 6), 'n']] 7450.131
#  > Model[[(0, 0, 2), (0, 0, 1, 12), 'n']] 5291.456
#  > Model[[(0, 0, 1), (2, 1, 2, 6), 'ct']] 1809.640
#  > Model[[(0, 0, 2), (0, 0, 2, 6), 'n']] 5607.093
#  > Model[[(0, 0, 2), (0, 1, 0, 6), 'n']] 4316.035
#  > Model[[(0, 0, 2), (0, 1, 0, 12), 'n']] 2361.644
#  > Model[[(0, 0, 1), (2, 1, 1, 12), 'ct']] 1951.808
#  > Model[[(0, 0, 2), (0, 1, 1, 6), 'n']] 3296.921
#  > Model[[(0, 0, 2), (0, 1, 1, 12), 'n']] 2306.819
#  > Model[[(0, 0, 2), (0, 0, 2, 12), 'n']] 70164.687
#  > Model[[(0, 0, 2), (1, 0, 0, 6), 'n']] 3779.456
#  > Model[[(0, 0, 2), (0, 1, 2, 6), 'n']] 3082.469
#  > Model[[(0, 0, 2), (1, 0, 0, 12), 'n']] 2107.547
#  > Model[[(0, 0, 2), (1, 0, 1, 6), 'n']] 4876.414
#  > Model[[(0, 0, 2), (1, 0, 1, 12), 'n']] 1913.671
#  > Model[[(0, 0, 2), (1, 0, 2, 6), 'n']] 4869.708
#  > Model[[(0, 0, 2), (1, 1, 0, 6), 'n']] 2290.571
#  > Model[[(0, 0, 2), (1, 1, 0, 12), 'n']] 2314.786
#  > Model[[(0, 0, 1), (2, 1, 2, 12), 'ct']] 3429104.070
#  > Model[[(0, 0, 2), (1, 1, 1, 12), 'n']] 2313.177
#  > Model[[(0, 0, 2), (1, 1, 1, 6), 'n']] 2365.100
#  > Model[[(0, 0, 2), (1, 0, 2, 12), 'n']] 4071.108
#  > Model[[(0, 0, 2), (0, 1, 2, 12), 'n']] 1053872476.618
#  > Model[[(0, 0, 2), (2, 0, 0, 6), 'n']] 1961.252
#  > Model[[(0, 0, 2), (1, 1, 2, 6), 'n']] 2303.456
#  > Model[[(0, 0, 2), (2, 0, 0, 12), 'n']] 1993.796
#  > Model[[(0, 0, 2), (2, 0, 1, 6), 'n']] 2549.280
#  > Model[[(0, 0, 2), (2, 0, 1, 12), 'n']] 3380.723
#  > Model[[(0, 0, 2), (2, 0, 2, 6), 'n']] 3334.830
#  > Model[[(0, 0, 2), (2, 1, 0, 6), 'n']] 2266.208
#  > Model[[(0, 0, 2), (2, 1, 0, 12), 'n']] 2306.917
#  > Model[[(0, 0, 2), (2, 0, 2, 12), 'n']] 4881450.113
#  > Model[[(0, 0, 2), (2, 1, 1, 6), 'n']] 2243.164
#  > Model[[(0, 0, 2), (1, 1, 2, 12), 'n']] 139672742260.086
#  > Model[[(0, 0, 2), (2, 1, 2, 6), 'n']] 2487.047
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'c']] 3638.692
#  > Model[[(0, 0, 2), (0, 0, 0, 6), 'c']] 3638.692
#  > Model[[(0, 0, 2), (0, 0, 0, 12), 'c']] 3638.692
#  > Model[[(0, 0, 2), (0, 0, 1, 6), 'c']] 3545.941
#  > Model[[(0, 0, 2), (0, 0, 1, 12), 'c']] 2754.009
#  > Model[[(0, 0, 2), (2, 1, 1, 12), 'n']] 1965.144
#  > Model[[(0, 0, 2), (0, 1, 0, 6), 'c']] 4341.692
#  > Model[[(0, 0, 2), (0, 0, 2, 6), 'c']] 2661.789
#  > Model[[(0, 0, 2), (0, 1, 0, 12), 'c']] 2002.072
#  > Model[[(0, 0, 2), (0, 1, 1, 6), 'c']] 3125.434
#  > Model[[(0, 0, 2), (0, 1, 1, 12), 'c']] 1849.690
#  > Model[[(0, 0, 2), (0, 1, 2, 6), 'c']] 2924.151
#  > Model[[(0, 0, 2), (1, 0, 0, 6), 'c']] 4151.064
#  > Model[[(0, 0, 2), (0, 0, 2, 12), 'c']] 2848.186
#  > Model[[(0, 0, 2), (1, 0, 0, 12), 'c']] 3438.696
#  > Model[[(0, 0, 2), (1, 0, 1, 6), 'c']] 3378.115
#  > Model[[(0, 0, 2), (1, 0, 1, 12), 'c']] 2492.116
#  > Model[[(0, 0, 2), (1, 0, 2, 6), 'c']] 2599.866
#  > Model[[(0, 0, 2), (1, 1, 0, 6), 'c']] 2019.116
#  > Model[[(0, 0, 2), (1, 1, 0, 12), 'c']] 1855.711
#  > Model[[(0, 0, 2), (1, 1, 1, 6), 'c']] 2172.704
#  > Model[[(0, 0, 2), (1, 0, 2, 12), 'c']] 2815.224
#  > Model[[(0, 0, 2), (0, 1, 2, 12), 'c']] 300858970.008
#  > Model[[(0, 0, 2), (1, 1, 1, 12), 'c']] 1930.586
#  > Model[[(0, 0, 2), (2, 0, 0, 6), 'c']] 2698.115
#  > Model[[(0, 0, 2), (2, 1, 2, 12), 'n']] 11154128.634
#  > Model[[(0, 0, 2), (2, 0, 1, 6), 'c']] 2430.099
#  > Model[[(0, 0, 2), (1, 1, 2, 6), 'c']] 2073.946
#  > Model[[(0, 0, 2), (2, 0, 0, 12), 'c']] 2854.223
#  > Model[[(0, 0, 2), (2, 0, 2, 6), 'c']] 2433.996
#  > Model[[(0, 0, 2), (2, 0, 1, 12), 'c']] 2397.043
#  > Model[[(0, 0, 2), (2, 1, 0, 6), 'c']] 2053.979
#  > Model[[(0, 0, 2), (2, 1, 0, 12), 'c']] 1975.133
#  > Model[[(0, 0, 2), (2, 0, 2, 12), 'c']] 3019.529
#  > Model[[(0, 0, 2), (2, 1, 1, 6), 'c']] 2167.875
#  > Model[[(0, 0, 2), (2, 1, 1, 12), 'c']] 1769.417
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 't']] 4451.221
#  > Model[[(0, 0, 2), (0, 0, 0, 6), 't']] 4451.221
#  > Model[[(0, 0, 2), (0, 0, 0, 12), 't']] 4451.221
#  > Model[[(0, 0, 2), (2, 1, 2, 6), 'c']] 1938.788
#  > Model[[(0, 0, 2), (0, 0, 1, 6), 't']] 3804.548
#  > Model[[(0, 0, 2), (1, 1, 2, 12), 'c']] 24191695605.095
#  > Model[[(0, 0, 2), (0, 0, 1, 12), 't']] 3025.218
#  > Model[[(0, 0, 2), (0, 1, 0, 6), 't']] 4446.350
#  > Model[[(0, 0, 2), (0, 0, 2, 6), 't']] 3468.511
#  > Model[[(0, 0, 2), (0, 1, 0, 12), 't']] 2036.325
#  > Model[[(0, 0, 2), (0, 1, 1, 6), 't']] 3281.603
#  > Model[[(0, 0, 2), (0, 1, 1, 12), 't']] 1949.186
#  > Model[[(0, 0, 2), (0, 0, 2, 12), 't']] 16172.715
#  > Model[[(0, 0, 2), (1, 0, 0, 6), 't']] 3999.154
#  > Model[[(0, 0, 2), (0, 1, 2, 6), 't']] 3251.828
#  > Model[[(0, 0, 2), (1, 0, 0, 12), 't']] 2962.461
#  > Model[[(0, 0, 2), (1, 0, 1, 6), 't']] 3803.178
#  > Model[[(0, 0, 2), (1, 0, 1, 12), 't']] 2311.368
#  > Model[[(0, 0, 2), (1, 0, 2, 6), 't']] 3453.296
#  > Model[[(0, 0, 2), (1, 1, 0, 6), 't']] 1991.316
#  > Model[[(0, 0, 2), (2, 1, 2, 12), 'c']] 10858142.937
#  > Model[[(0, 0, 2), (1, 1, 0, 12), 't']] 1963.441
#  > Model[[(0, 0, 2), (1, 1, 1, 6), 't']] 3208.476
#  > Model[[(0, 0, 2), (1, 0, 2, 12), 't']] 2433.432
#  > Model[[(0, 0, 2), (0, 1, 2, 12), 't']] 629234900.006
#  > Model[[(0, 0, 2), (1, 1, 1, 12), 't']] 1939.623
#  > Model[[(0, 0, 2), (2, 0, 0, 6), 't']] 2187.864
#  > Model[[(0, 0, 2), (1, 1, 2, 6), 't']] 4530.798
#  > Model[[(0, 0, 2), (2, 0, 1, 6), 't']] 2287.813
#  > Model[[(0, 0, 2), (2, 0, 0, 12), 't']] 2387.995
#  > Model[[(0, 0, 2), (2, 0, 1, 12), 't']] 2484.367
#  > Model[[(0, 0, 2), (2, 0, 2, 6), 't']] 2714.382
#  > Model[[(0, 0, 2), (2, 1, 0, 6), 't']] 2044.601
#  > Model[[(0, 0, 2), (2, 0, 2, 12), 't']] 2590.109
#  > Model[[(0, 0, 2), (2, 1, 0, 12), 't']] 1887.830
#  > Model[[(0, 0, 2), (2, 1, 1, 6), 't']] 2484.367
#  > Model[[(0, 0, 2), (1, 1, 2, 12), 't']] 19682340106.554
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'ct']] 3303.563
#  > Model[[(0, 0, 2), (0, 0, 0, 6), 'ct']] 3303.563
#  > Model[[(0, 0, 2), (0, 0, 0, 12), 'ct']] 3303.563
#  > Model[[(0, 0, 2), (2, 1, 2, 6), 't']] 2874.978
#  > Model[[(0, 0, 2), (0, 0, 1, 6), 'ct']] 3287.631
#  > Model[[(0, 0, 2), (0, 0, 1, 12), 'ct']] 2502.308
#  > Model[[(0, 0, 2), (0, 0, 2, 6), 'ct']] 2505.634
#  > Model[[(0, 0, 2), (0, 1, 0, 6), 'ct']] 4487.931
#  > Model[[(0, 0, 2), (0, 1, 0, 12), 'ct']] 2117.777
#  > Model[[(0, 0, 2), (2, 1, 1, 12), 't']] 2062.008
#  > Model[[(0, 0, 2), (0, 1, 1, 6), 'ct']] 3109.824
#  > Model[[(0, 0, 2), (0, 1, 1, 12), 'ct']] 1857.246
#  > Model[[(0, 0, 2), (0, 0, 2, 12), 'ct']] 3332.044
#  > Model[[(0, 0, 2), (1, 0, 0, 6), 'ct']] 3317.809
#  > Model[[(0, 0, 2), (1, 0, 0, 12), 'ct']] 3366.220
#  > Model[[(0, 0, 2), (0, 1, 2, 6), 'ct']] 2981.649
#  > Model[[(0, 0, 2), (1, 0, 1, 6), 'ct']] 3346.610
#  > Model[[(0, 0, 2), (1, 0, 1, 12), 'ct']] 2463.177
#  > Model[[(0, 0, 2), (1, 0, 2, 6), 'ct']] 2522.489
#  > Model[[(0, 0, 2), (1, 1, 0, 6), 'ct']] 2003.559
#  > Model[[(0, 0, 2), (1, 1, 0, 12), 'ct']] 1947.594
#  > Model[[(0, 0, 2), (2, 1, 2, 12), 't']] 42339579.962
#  > Model[[(0, 0, 2), (1, 1, 1, 6), 'ct']] 3039.250
#  > Model[[(0, 0, 2), (1, 0, 2, 12), 'ct']] 4290.171
#  > Model[[(0, 0, 2), (1, 1, 1, 12), 'ct']] 1913.385
#  > Model[[(0, 0, 2), (0, 1, 2, 12), 'ct']] 240508110.446
#  > Model[[(0, 0, 2), (2, 0, 0, 6), 'ct']] 2457.335
#  > Model[[(0, 0, 2), (1, 1, 2, 6), 'ct']] 2774.570
#  > Model[[(0, 0, 2), (2, 0, 1, 6), 'ct']] 2254.060
#  > Model[[(0, 0, 2), (2, 0, 0, 12), 'ct']] 2846.838
#  > Model[[(0, 0, 2), (2, 0, 1, 12), 'ct']] 2540.295
#  > Model[[(0, 0, 2), (2, 0, 2, 6), 'ct']] 2330.048
#  > Model[[(0, 0, 2), (2, 1, 0, 6), 'ct']] 2007.471
#  > Model[[(0, 0, 2), (2, 1, 0, 12), 'ct']] 1813.302
#  > Model[[(0, 0, 2), (2, 0, 2, 12), 'ct']] 3050.658
#  > Model[[(0, 0, 2), (2, 1, 1, 6), 'ct']] 2630.808
#  > Model[[(0, 0, 2), (2, 1, 2, 6), 'ct']] 2830.460
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'n']] 3783.966
#  > Model[[(0, 1, 0), (0, 0, 0, 6), 'n']] 3783.966
#  > Model[[(0, 1, 0), (0, 0, 0, 12), 'n']] 3783.966
#  > Model[[(0, 1, 0), (0, 0, 1, 6), 'n']] 3805.358
#  > Model[[(0, 1, 0), (0, 0, 1, 12), 'n']] 2475.318
#  > Model[[(0, 1, 0), (0, 0, 2, 6), 'n']] 2304.795
#  > Model[[(0, 0, 2), (1, 1, 2, 12), 'ct']] 41104824701175.727
#  > Model[[(0, 1, 0), (0, 1, 0, 6), 'n']] 5150.813
#  > Model[[(0, 1, 0), (0, 1, 0, 12), 'n']] 2697.425
#  > Model[[(0, 0, 2), (2, 1, 1, 12), 'ct']] 1972.491
#  > Model[[(0, 1, 0), (0, 1, 1, 6), 'n']] 3370.750
#  > Model[[(0, 1, 0), (0, 1, 1, 12), 'n']] 2364.050
#  > Model[[(0, 1, 0), (0, 0, 2, 12), 'n']] 7479.556
#  > Model[[(0, 1, 0), (1, 0, 0, 6), 'n']] 3829.526
#  > Model[[(0, 1, 0), (1, 0, 0, 12), 'n']] 2506.083
#  > Model[[(0, 1, 0), (1, 0, 1, 6), 'n']] 3355.935
#  > Model[[(0, 1, 0), (0, 1, 2, 6), 'n']] 3211.221
#  > Model[[(0, 1, 0), (1, 0, 1, 12), 'n']] 2410.308
#  > Model[[(0, 1, 0), (1, 0, 2, 6), 'n']] 2526.661
#  > Model[[(0, 1, 0), (1, 1, 0, 6), 'n']] 2665.878
#  > Model[[(0, 1, 0), (1, 1, 0, 12), 'n']] 2674.894
#  > Model[[(0, 1, 0), (1, 1, 1, 6), 'n']] 2868.380
#  > Model[[(0, 1, 0), (1, 0, 2, 12), 'n']] 2769.192
#  > Model[[(0, 1, 0), (1, 1, 1, 12), 'n']] 2500.476
#  > Model[[(0, 1, 0), (1, 1, 2, 6), 'n']] 2560.881
#  > Model[[(0, 1, 0), (2, 0, 0, 6), 'n']] 2539.397
#  > Model[[(0, 1, 0), (2, 0, 0, 12), 'n']] 2654.703
#  > Model[[(0, 1, 0), (2, 0, 1, 6), 'n']] 2642.342
#  > Model[[(0, 1, 0), (2, 0, 1, 12), 'n']] 2508.681
#  > Model[[(0, 1, 0), (2, 0, 2, 6), 'n']] 2585.072
#  > Model[[(0, 1, 0), (0, 1, 2, 12), 'n']] 453799094.612
#  > Model[[(0, 1, 0), (2, 1, 0, 6), 'n']] 2656.094
#  > Model[[(0, 1, 0), (2, 1, 0, 12), 'n']] 2376.965
#  > Model[[(0, 1, 0), (2, 0, 2, 12), 'n']] 2703.195
#  > Model[[(0, 1, 0), (2, 1, 1, 6), 'n']] 2765.357
#  > Model[[(0, 1, 0), (2, 1, 2, 6), 'n']] 2516.636
#  > Model[[(0, 1, 0), (2, 1, 1, 12), 'n']] 2762.641
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'c']] 3801.923
#  > Model[[(0, 1, 0), (0, 0, 0, 6), 'c']] 3801.923
#  > Model[[(0, 1, 0), (0, 0, 0, 12), 'c']] 3801.923
#  > Model[[(0, 1, 0), (0, 0, 1, 6), 'c']] 3821.933
#  > Model[[(0, 1, 0), (0, 0, 1, 12), 'c']] 2495.273
#  > Model[[(0, 1, 0), (0, 0, 2, 6), 'c']] 2321.785
#  > Model[[(0, 1, 0), (0, 0, 2, 12), 'c']] 6922.972
#  > Model[[(0, 1, 0), (0, 1, 0, 6), 'c']] 5182.478
#  > Model[[(0, 1, 0), (0, 1, 0, 12), 'c']] 2713.153
#  > Model[[(0, 1, 0), (1, 1, 2, 12), 'n']] 444315031.679
#  > Model[[(0, 1, 0), (0, 1, 1, 6), 'c']] 3482.458
#  > Model[[(0, 0, 2), (2, 1, 2, 12), 'ct']] 17009109.509
#  > Model[[(0, 1, 0), (0, 1, 1, 12), 'c']] 2379.703
#  > Model[[(0, 1, 0), (1, 0, 0, 6), 'c']] 3847.189
#  > Model[[(0, 1, 0), (1, 0, 0, 12), 'c']] 2516.602
#  > Model[[(0, 1, 0), (0, 1, 2, 6), 'c']] 3264.187
#  > Model[[(0, 1, 0), (1, 0, 1, 6), 'c']] 3419.161
#  > Model[[(0, 1, 0), (1, 0, 1, 12), 'c']] 2405.562
#  > Model[[(0, 1, 0), (1, 0, 2, 6), 'c']] 2969.957
#  > Model[[(0, 1, 0), (1, 1, 0, 6), 'c']] 2681.317
#  > Model[[(0, 1, 0), (1, 1, 0, 12), 'c']] 2696.562
#  > Model[[(0, 1, 0), (1, 1, 1, 6), 'c']] 2860.379
#  > Model[[(0, 1, 0), (2, 1, 2, 12), 'n']] 214664314633.794
#  > Model[[(0, 1, 0), (1, 0, 2, 12), 'c']] 2934.698
#  > Model[[(0, 1, 0), (1, 1, 1, 12), 'c']] 2506.090
#  > Model[[(0, 1, 0), (2, 0, 0, 6), 'c']] 2549.910
#  > Model[[(0, 1, 0), (1, 1, 2, 6), 'c']] 2582.860
#  > Model[[(0, 1, 0), (2, 0, 0, 12), 'c']] 2676.900
#  > Model[[(0, 1, 0), (2, 0, 1, 6), 'c']] 2665.738
#  > Model[[(0, 1, 0), (0, 1, 2, 12), 'c']] 453592140.969
#  > Model[[(0, 1, 0), (2, 0, 2, 6), 'c']] 2603.950
#  > Model[[(0, 1, 0), (2, 0, 1, 12), 'c']] 2529.363
#  > Model[[(0, 1, 0), (2, 1, 0, 6), 'c']] 2673.985
#  > Model[[(0, 1, 0), (2, 1, 1, 6), 'c']] 2665.369
#  > Model[[(0, 1, 0), (2, 1, 0, 12), 'c']] 2393.167
#  > Model[[(0, 1, 0), (2, 0, 2, 12), 'c']] 2571.466
#  > Model[[(0, 1, 0), (2, 1, 2, 6), 'c']] 2553.056
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 't']] 3839.965
#  > Model[[(0, 1, 0), (0, 0, 0, 6), 't']] 3839.965
#  > Model[[(0, 1, 0), (0, 0, 0, 12), 't']] 3839.965
#  > Model[[(0, 1, 0), (0, 0, 1, 6), 't']] 3859.213
#  > Model[[(0, 1, 0), (0, 0, 1, 12), 't']] 2503.255
#  > Model[[(0, 1, 0), (0, 0, 2, 6), 't']] 2355.796
#  > Model[[(0, 1, 0), (2, 1, 1, 12), 'c']] 2836.349
#  > Model[[(0, 1, 0), (0, 1, 0, 6), 't']] 5236.278
#  > Model[[(0, 1, 0), (0, 1, 0, 12), 't']] 2739.427
#  > Model[[(0, 1, 0), (0, 1, 1, 6), 't']] 3373.664
#  > Model[[(0, 1, 0), (1, 1, 2, 12), 'c']] 388451675.753
#  > Model[[(0, 1, 0), (0, 1, 1, 12), 't']] 2391.263
#  > Model[[(0, 1, 0), (0, 1, 2, 6), 't']] 3258.805
#  > Model[[(0, 1, 0), (1, 0, 0, 6), 't']] 3886.881
#  > Model[[(0, 1, 0), (0, 0, 2, 12), 't']] 7582.860
#  > Model[[(0, 1, 0), (1, 0, 0, 12), 't']] 2544.958
#  > Model[[(0, 1, 0), (1, 0, 1, 6), 't']] 3406.812
#  > Model[[(0, 1, 0), (1, 0, 1, 12), 't']] 2451.658
#  > Model[[(0, 1, 0), (1, 0, 2, 6), 't']] 2548.849
#  > Model[[(0, 1, 0), (1, 1, 0, 6), 't']] 2708.543
#  > Model[[(0, 1, 0), (2, 1, 2, 12), 'c']] 9575972470387.264
#  > Model[[(0, 1, 0), (1, 1, 0, 12), 't']] 2722.176
#  > Model[[(0, 1, 0), (1, 1, 1, 6), 't']] 2924.186
#  > Model[[(0, 1, 0), (1, 0, 2, 12), 't']] 2789.342
#  > Model[[(0, 1, 0), (1, 1, 1, 12), 't']] 2539.700
#  > Model[[(0, 1, 0), (2, 0, 0, 6), 't']] 2579.169
#  > Model[[(0, 1, 0), (1, 1, 2, 6), 't']] 2547.691
#  > Model[[(0, 1, 0), (0, 1, 2, 12), 't']] 452202737.276
#  > Model[[(0, 1, 0), (2, 0, 0, 12), 't']] 2701.493
#  > Model[[(0, 1, 0), (2, 0, 1, 6), 't']] 2686.723
#  > Model[[(0, 1, 0), (2, 0, 2, 6), 't']] 2594.243
#  > Model[[(0, 1, 0), (2, 0, 1, 12), 't']] 2536.674
#  > Model[[(0, 1, 0), (2, 1, 0, 6), 't']] 2699.928
#  > Model[[(0, 1, 0), (2, 0, 2, 12), 't']] 3001.562
#  > Model[[(0, 1, 0), (2, 1, 1, 6), 't']] 2634.490
#  > Model[[(0, 1, 0), (2, 1, 0, 12), 't']] 2416.096
#  > Model[[(0, 1, 0), (1, 1, 2, 12), 't']] 462879247.173
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'ct']] 3860.890
#  > Model[[(0, 1, 0), (0, 0, 0, 6), 'ct']] 3860.890
#  > Model[[(0, 1, 0), (0, 0, 0, 12), 'ct']] 3860.890
#  > Model[[(0, 1, 0), (0, 0, 1, 6), 'ct']] 3879.501
#  > Model[[(0, 1, 0), (2, 1, 2, 6), 't']] 2737.700
#  > Model[[(0, 1, 0), (0, 0, 1, 12), 'ct']] 2516.332
#  > Model[[(0, 1, 0), (0, 0, 2, 6), 'ct']] 2353.396
#  > Model[[(0, 1, 0), (0, 1, 0, 6), 'ct']] 5264.192
#  > Model[[(0, 1, 0), (0, 1, 0, 12), 'ct']] 2755.347
#  > Model[[(0, 1, 0), (0, 1, 1, 6), 'ct']] 3417.537
#  > Model[[(0, 1, 0), (2, 1, 1, 12), 't']] 2834.628
#  > Model[[(0, 1, 0), (0, 1, 1, 12), 'ct']] 2422.806
#  > Model[[(0, 1, 0), (0, 0, 2, 12), 'ct']] 6464.665
#  > Model[[(0, 1, 0), (1, 0, 0, 6), 'ct']] 3908.182
#  > Model[[(0, 1, 0), (0, 1, 2, 6), 'ct']] 3297.852
#  > Model[[(0, 1, 0), (1, 0, 0, 12), 'ct']] 2572.333
#  > Model[[(0, 1, 0), (1, 0, 1, 6), 'ct']] 3620.955
#  > Model[[(0, 1, 0), (1, 0, 1, 12), 'ct']] 2494.593
#  > Model[[(0, 1, 0), (1, 0, 2, 6), 'ct']] 2382.602
#  > Model[[(0, 1, 0), (1, 1, 0, 6), 'ct']] 2720.873
#  > Model[[(0, 1, 0), (1, 1, 0, 12), 'ct']] 2736.197
#  > Model[[(0, 1, 0), (2, 1, 2, 12), 't']] 1405691442.067
#  > Model[[(0, 1, 0), (1, 1, 1, 6), 'ct']] 2870.101
#  > Model[[(0, 1, 0), (1, 1, 1, 12), 'ct']] 2561.242
#  > Model[[(0, 1, 0), (1, 0, 2, 12), 'ct']] 3081.457
#  > Model[[(0, 1, 0), (2, 0, 0, 6), 'ct']] 2598.104
#  > Model[[(0, 1, 0), (1, 1, 2, 6), 'ct']] 2621.873
#  > Model[[(0, 1, 0), (2, 0, 0, 12), 'ct']] 2722.804
#  > Model[[(0, 1, 0), (2, 0, 1, 6), 'ct']] 2687.611
#  > Model[[(0, 1, 0), (0, 1, 2, 12), 'ct']] 448446889.247
#  > Model[[(0, 1, 0), (2, 0, 2, 6), 'ct']] 2693.860
#  > Model[[(0, 1, 0), (2, 0, 1, 12), 'ct']] 2601.143
#  > Model[[(0, 1, 0), (2, 1, 0, 6), 'ct']] 2711.760
#  > Model[[(0, 1, 0), (2, 1, 1, 6), 'ct']] 2644.196
#  > Model[[(0, 1, 0), (2, 0, 2, 12), 'ct']] 2640.501
#  > Model[[(0, 1, 0), (2, 1, 0, 12), 'ct']] 2427.006
#  > Model[[(0, 1, 0), (1, 1, 2, 12), 'ct']] 387097118.147
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'n']] 3924.486
#  > Model[[(0, 1, 1), (0, 0, 0, 6), 'n']] 3924.486
#  > Model[[(0, 1, 1), (0, 0, 0, 12), 'n']] 3924.486
#  > Model[[(0, 1, 1), (0, 0, 1, 6), 'n']] 3933.603
#  > Model[[(0, 1, 1), (0, 0, 1, 12), 'n']] 2408.154
#  > Model[[(0, 1, 1), (0, 0, 2, 6), 'n']] 2246.089
#  > Model[[(0, 1, 0), (2, 1, 2, 6), 'ct']] 3239.585
#  > Model[[(0, 1, 1), (0, 1, 0, 6), 'n']] 5183.460
#  > Model[[(0, 1, 1), (0, 1, 0, 12), 'n']] 1971.704
#  > Model[[(0, 1, 1), (0, 1, 1, 6), 'n']] 3277.394
#  > Model[[(0, 1, 1), (0, 1, 1, 12), 'n']] 1761.096
#  > Model[[(0, 1, 1), (0, 0, 2, 12), 'n']] 7299.576
#  > Model[[(0, 1, 0), (2, 1, 1, 12), 'ct']] 2824.651
#  > Model[[(0, 1, 1), (1, 0, 0, 6), 'n']] 3945.745
#  > Model[[(0, 1, 1), (0, 1, 2, 6), 'n']] 3024.096
#  > Model[[(0, 1, 1), (1, 0, 1, 6), 'n']] 3313.134
#  > Model[[(0, 1, 1), (1, 0, 0, 12), 'n']] 1893.358
#  > Model[[(0, 1, 1), (1, 0, 1, 12), 'n']] 1800.658
#  > Model[[(0, 1, 1), (1, 0, 2, 6), 'n']] 2260.465
#  > Model[[(0, 1, 1), (1, 1, 0, 6), 'n']] 1993.317
#  > Model[[(0, 1, 1), (1, 1, 0, 12), 'n']] 1927.570
#  > Model[[(0, 1, 1), (1, 1, 1, 6), 'n']] 2040.499
#  > Model[[(0, 1, 0), (2, 1, 2, 12), 'ct']] 4071707530.578
#  > Model[[(0, 1, 1), (1, 0, 2, 12), 'n']] 2244.382
#  > Model[[(0, 1, 1), (0, 1, 2, 12), 'n']] 299013080.770
#  > Model[[(0, 1, 1), (1, 1, 1, 12), 'n']] 1898.386
#  > Model[[(0, 1, 1), (2, 0, 0, 6), 'n']] 2051.257
#  > Model[[(0, 1, 1), (1, 1, 2, 6), 'n']] 1792.521
#  > Model[[(0, 1, 1), (2, 0, 0, 12), 'n']] 1945.457
#  > Model[[(0, 1, 1), (2, 0, 1, 6), 'n']] 1935.647
#  > Model[[(0, 1, 1), (2, 0, 1, 12), 'n']] 1946.195
#  > Model[[(0, 1, 1), (2, 0, 2, 6), 'n']] 1878.052
#  > Model[[(0, 1, 1), (2, 1, 0, 6), 'n']] 2004.096
#  > Model[[(0, 1, 1), (2, 0, 2, 12), 'n']] 2030.237
#  > Model[[(0, 1, 1), (2, 1, 0, 12), 'n']] 1844.189
#  > Model[[(0, 1, 1), (1, 1, 2, 12), 'n']] 1169280219.534
#  > Model[[(0, 1, 1), (2, 1, 1, 6), 'n']] 1832.394
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'c']] 3941.456
#  > Model[[(0, 1, 1), (0, 0, 0, 6), 'c']] 3941.456
#  > Model[[(0, 1, 1), (0, 0, 0, 12), 'c']] 3941.456
#  > Model[[(0, 1, 1), (0, 0, 1, 6), 'c']] 3949.480
#  > Model[[(0, 1, 1), (0, 0, 1, 12), 'c']] 2419.198
#  > Model[[(0, 1, 1), (0, 0, 2, 6), 'c']] 2258.249
#  > Model[[(0, 1, 1), (2, 1, 2, 6), 'n']] 1897.323
#  > Model[[(0, 1, 1), (0, 1, 0, 6), 'c']] 5212.318
#  > Model[[(0, 1, 1), (0, 1, 0, 12), 'c']] 2036.000
#  > Model[[(0, 1, 1), (0, 1, 1, 6), 'c']] 3264.318
#  > Model[[(0, 1, 1), (2, 1, 1, 12), 'n']] 2046.723
#  > Model[[(0, 1, 1), (0, 0, 2, 12), 'c']] 7361.197
#  > Model[[(0, 1, 1), (0, 1, 1, 12), 'c']] 1969.031
#  > Model[[(0, 1, 1), (2, 1, 2, 12), 'n']] 45187802981.384
#  > Model[[(0, 1, 1), (1, 0, 0, 6), 'c']] 3963.623
#  > Model[[(0, 1, 1), (0, 1, 2, 6), 'c']] 3096.343
#  > Model[[(0, 1, 1), (1, 0, 1, 6), 'c']] 3413.132
#  > Model[[(0, 1, 1), (1, 0, 0, 12), 'c']] 1984.678
#  > Model[[(0, 1, 1), (1, 0, 2, 6), 'c']] 2276.412
#  > Model[[(0, 1, 1), (1, 0, 1, 12), 'c']] 2090.306
#  > Model[[(0, 1, 1), (1, 1, 0, 6), 'c']] 2058.383
#  > Model[[(0, 1, 1), (1, 1, 0, 12), 'c']] 2107.549
#  > Model[[(0, 1, 1), (1, 1, 1, 6), 'c']] 2107.708
#  > Model[[(0, 1, 1), (1, 0, 2, 12), 'c']] 2243.073
#  > Model[[(0, 1, 1), (1, 1, 2, 6), 'c']] 2264.334
#  > Model[[(0, 1, 1), (0, 1, 2, 12), 'c']] 361243890.756
#  > Model[[(0, 1, 1), (1, 1, 1, 12), 'c']] 2014.358
#  > Model[[(0, 1, 1), (2, 0, 0, 6), 'c']] 1964.441
#  > Model[[(0, 1, 1), (2, 0, 1, 6), 'c']] 2109.756
#  > Model[[(0, 1, 1), (2, 0, 0, 12), 'c']] 1920.889
#  > Model[[(0, 1, 1), (2, 0, 2, 6), 'c']] 2272.269
#  > Model[[(0, 1, 1), (2, 0, 1, 12), 'c']] 2092.195
#  > Model[[(0, 1, 1), (2, 1, 0, 6), 'c']] 2108.201
#  > Model[[(0, 1, 1), (2, 0, 2, 12), 'c']] 1823.260
#  > Model[[(0, 1, 1), (2, 1, 1, 6), 'c']] 1852.727
#  > Model[[(0, 1, 1), (1, 1, 2, 12), 'c']] 19511914139.717
#  > Model[[(0, 1, 1), (2, 1, 0, 12), 'c']] 2002.828
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 't']] 3977.415
#  > Model[[(0, 1, 1), (0, 0, 0, 6), 't']] 3977.415
#  > Model[[(0, 1, 1), (0, 0, 0, 12), 't']] 3977.415
#  > Model[[(0, 1, 1), (0, 0, 1, 6), 't']] 3988.148
#  > Model[[(0, 1, 1), (2, 1, 2, 6), 'c']] 2599.831
#  > Model[[(0, 1, 1), (0, 0, 1, 12), 't']] 2427.989
#  > Model[[(0, 1, 1), (0, 0, 2, 6), 't']] 2288.745
#  > Model[[(0, 1, 1), (0, 1, 0, 6), 't']] 5281.380
#  > Model[[(0, 1, 1), (0, 1, 0, 12), 't']] 2024.867
#  > Model[[(0, 1, 1), (0, 1, 1, 6), 't']] 3312.343
#  > Model[[(0, 1, 1), (2, 1, 1, 12), 'c']] 2232.198
#  > Model[[(0, 1, 1), (0, 1, 1, 12), 't']] 2032.144
#  > Model[[(0, 1, 1), (0, 0, 2, 12), 't']] 7191.123
#  > Model[[(0, 1, 1), (1, 0, 0, 6), 't']] 3999.673
#  > Model[[(0, 1, 1), (1, 0, 0, 12), 't']] 1909.721
#  > Model[[(0, 1, 1), (0, 1, 2, 6), 't']] 3072.245
#  > Model[[(0, 1, 1), (1, 0, 1, 6), 't']] 3372.846
#  > Model[[(0, 1, 1), (2, 1, 2, 12), 'c']] 42634254384.417
#  > Model[[(0, 1, 1), (1, 0, 1, 12), 't']] 2039.019
#  > Model[[(0, 1, 1), (1, 0, 2, 6), 't']] 2874.374
#  > Model[[(0, 1, 1), (1, 1, 0, 6), 't']] 2046.646
#  > Model[[(0, 1, 1), (1, 1, 0, 12), 't']] 2220.376
#  > Model[[(0, 1, 1), (1, 1, 1, 6), 't']] 2138.824
#  > Model[[(0, 1, 1), (1, 0, 2, 12), 't']] 2404.403
#  > Model[[(0, 1, 1), (1, 1, 1, 12), 't']] 2225.390
#  > Model[[(0, 1, 1), (0, 1, 2, 12), 't']] 400348975.946
#  > Model[[(0, 1, 1), (1, 1, 2, 6), 't']] 1853.913
#  > Model[[(0, 1, 1), (2, 0, 0, 6), 't']] 2139.913
#  > Model[[(0, 1, 1), (2, 0, 1, 6), 't']] 2411.006
#  > Model[[(0, 1, 1), (2, 0, 0, 12), 't']] 2187.044
#  > Model[[(0, 1, 1), (2, 0, 2, 6), 't']] 1740.725
#  > Model[[(0, 1, 1), (2, 0, 1, 12), 't']] 2008.984
#  > Model[[(0, 1, 1), (2, 1, 0, 6), 't']] 2113.418
#  > Model[[(0, 1, 1), (1, 1, 2, 12), 't']] 512397275.619
#  > Model[[(0, 1, 1), (2, 0, 2, 12), 't']] 2519.281
#  > Model[[(0, 1, 1), (2, 1, 0, 12), 't']] 2117.661
#  > Model[[(0, 1, 1), (2, 1, 1, 6), 't']] 2540.946
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'ct']] 3996.987
#  > Model[[(0, 1, 1), (0, 0, 0, 6), 'ct']] 3996.987
#  > Model[[(0, 1, 1), (0, 0, 0, 12), 'ct']] 3996.987
#  > Model[[(0, 1, 1), (0, 0, 1, 6), 'ct']] 4003.636
#  > Model[[(0, 1, 1), (0, 0, 1, 12), 'ct']] 2444.691
#  > Model[[(0, 1, 1), (2, 1, 2, 6), 't']] 1965.557
#  > Model[[(0, 1, 1), (0, 0, 2, 6), 'ct']] 2298.975
#  > Model[[(0, 1, 1), (0, 1, 0, 6), 'ct']] 5300.741
#  > Model[[(0, 1, 1), (0, 1, 0, 12), 'ct']] 2019.804
#  > Model[[(0, 1, 1), (0, 1, 1, 6), 'ct']] 3367.119
#  > Model[[(0, 1, 1), (2, 1, 1, 12), 't']] 2257.794
#  > Model[[(0, 1, 1), (0, 0, 2, 12), 'ct']] 7108.445
#  > Model[[(0, 1, 1), (0, 1, 1, 12), 'ct']] 2093.527
#  > Model[[(0, 1, 1), (1, 0, 0, 6), 'ct']] 4019.395
#  > Model[[(0, 1, 1), (0, 1, 2, 6), 'ct']] 3362.492
#  > Model[[(0, 1, 1), (2, 1, 2, 12), 't']] 139065215297.819
#  > Model[[(0, 1, 1), (1, 0, 1, 6), 'ct']] 3454.203
#  > Model[[(0, 1, 1), (1, 0, 0, 12), 'ct']] 1946.854
#  > Model[[(0, 1, 1), (1, 0, 1, 12), 'ct']] 1975.619
#  > Model[[(0, 1, 1), (1, 0, 2, 6), 'ct']] 2339.368
#  > Model[[(0, 1, 1), (1, 1, 0, 6), 'ct']] 2036.857
#  > Model[[(0, 1, 1), (1, 1, 0, 12), 'ct']] 2129.091
#  > Model[[(0, 1, 1), (1, 1, 1, 6), 'ct']] 2204.640
#  > Model[[(0, 1, 1), (1, 0, 2, 12), 'ct']] 2466.729
#  > Model[[(0, 1, 1), (0, 1, 2, 12), 'ct']] 340373596.670
#  > Model[[(0, 1, 1), (1, 1, 1, 12), 'ct']] 1995.157
#  > Model[[(0, 1, 1), (1, 1, 2, 6), 'ct']] 2552.990
#  > Model[[(0, 1, 1), (2, 0, 0, 6), 'ct']] 1973.567
#  > Model[[(0, 1, 1), (2, 0, 1, 6), 'ct']] 2476.869
#  > Model[[(0, 1, 1), (2, 0, 0, 12), 'ct']] 2032.819
#  > Model[[(0, 1, 1), (2, 0, 1, 12), 'ct']] 1929.990
#  > Model[[(0, 1, 1), (2, 0, 2, 6), 'ct']] 2284.794
#  > Model[[(0, 1, 1), (1, 1, 2, 12), 'ct']] 2036865913.805
#  > Model[[(0, 1, 1), (2, 1, 0, 6), 'ct']] 2105.237
#  > Model[[(0, 1, 1), (2, 0, 2, 12), 'ct']] 2540.190
#  > Model[[(0, 1, 1), (2, 1, 1, 6), 'ct']] 2090.058
#  > Model[[(0, 1, 1), (2, 1, 0, 12), 'ct']] 2074.009
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'n']] 4151.712
#  > Model[[(0, 1, 2), (0, 0, 0, 6), 'n']] 4151.712
#  > Model[[(0, 1, 2), (0, 0, 0, 12), 'n']] 4151.712
#  > Model[[(0, 1, 2), (0, 0, 1, 6), 'n']] 3845.794
#  > Model[[(0, 1, 2), (0, 0, 1, 12), 'n']] 2242.973
#  > Model[[(0, 1, 1), (2, 1, 2, 6), 'ct']] 3414.248
#  > Model[[(0, 1, 2), (0, 0, 2, 6), 'n']] 2132.702
#  > Model[[(0, 1, 2), (0, 1, 0, 6), 'n']] 4772.124
#  > Model[[(0, 1, 2), (0, 1, 0, 12), 'n']] 2049.218
#  > Model[[(0, 1, 1), (2, 1, 1, 12), 'ct']] 2220.404
#  > Model[[(0, 1, 2), (0, 1, 1, 6), 'n']] 3019.100
#  > Model[[(0, 1, 2), (0, 1, 1, 12), 'n']] 1767.936
#  > Model[[(0, 1, 2), (0, 0, 2, 12), 'n']] 6438.746
#  > Model[[(0, 1, 2), (1, 0, 0, 6), 'n']] 3914.184
#  > Model[[(0, 1, 2), (0, 1, 2, 6), 'n']] 3117.835
#  > Model[[(0, 1, 2), (1, 0, 0, 12), 'n']] 1846.918
#  > Model[[(0, 1, 2), (1, 0, 1, 6), 'n']] 3143.555
#  > Model[[(0, 1, 2), (1, 0, 1, 12), 'n']] 1809.052
#  > Model[[(0, 1, 2), (1, 0, 2, 6), 'n']] 2730.533
#  > Model[[(0, 1, 1), (2, 1, 2, 12), 'ct']] 11039160487.542
#  > Model[[(0, 1, 2), (1, 1, 0, 6), 'n']] 2036.342
#  > Model[[(0, 1, 2), (1, 1, 0, 12), 'n']] 1980.113
#  > Model[[(0, 1, 2), (1, 1, 1, 6), 'n']] 2038.249
#  > Model[[(0, 1, 2), (1, 0, 2, 12), 'n']] 2334.426
#  > Model[[(0, 1, 2), (1, 1, 1, 12), 'n']] 1812.413
#  > Model[[(0, 1, 2), (2, 0, 0, 6), 'n']] 1891.300
#  > Model[[(0, 1, 2), (1, 1, 2, 6), 'n']] 1876.840
#  > Model[[(0, 1, 2), (0, 1, 2, 12), 'n']] 41132659902420296.000
#  > Model[[(0, 1, 2), (2, 0, 1, 6), 'n']] 2088.962
#  > Model[[(0, 1, 2), (2, 0, 0, 12), 'n']] 1995.019
#  > Model[[(0, 1, 2), (2, 0, 2, 6), 'n']] 1930.431
#  > Model[[(0, 1, 2), (2, 0, 1, 12), 'n']] 1922.362
#  > Model[[(0, 1, 2), (2, 1, 0, 6), 'n']] 1973.695
#  > Model[[(0, 1, 2), (2, 0, 2, 12), 'n']] 2069.365
#  > Model[[(0, 1, 2), (2, 1, 1, 6), 'n']] 1860.820
#  > Model[[(0, 1, 2), (2, 1, 0, 12), 'n']] 1873.089
#  > Model[[(0, 1, 2), (1, 1, 2, 12), 'n']] 493344575.235
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'c']] 4038.640
#  > Model[[(0, 1, 2), (0, 0, 0, 6), 'c']] 4038.640
#  > Model[[(0, 1, 2), (2, 1, 2, 6), 'n']] 1802.234
#  > Model[[(0, 1, 2), (0, 0, 0, 12), 'c']] 4038.640
#  > Model[[(0, 1, 2), (0, 0, 1, 6), 'c']] 3887.106
#  > Model[[(0, 1, 2), (0, 0, 1, 12), 'c']] 2084.522
#  > Model[[(0, 1, 2), (0, 0, 2, 6), 'c']] 1924.298
#  > Model[[(0, 1, 2), (2, 1, 1, 12), 'n']] 2141.663
#  > Model[[(0, 1, 2), (0, 1, 0, 6), 'c']] 4798.452
#  > Model[[(0, 1, 2), (0, 1, 0, 12), 'c']] 2192.649
#  > Model[[(0, 1, 2), (2, 1, 2, 12), 'n']] 31167912678.996
#  > Model[[(0, 1, 2), (0, 1, 1, 6), 'c']] 3036.945
#  > Model[[(0, 1, 2), (0, 1, 2, 6), 'c']] 2903.713
#  > Model[[(0, 1, 2), (0, 0, 2, 12), 'c']] 6281.789
#  > Model[[(0, 1, 2), (1, 0, 0, 6), 'c']] 3929.748
#  > Model[[(0, 1, 2), (0, 1, 1, 12), 'c']] 1875.003
#  > Model[[(0, 1, 2), (1, 0, 1, 6), 'c']] 3075.124
#  > Model[[(0, 1, 2), (1, 0, 0, 12), 'c']] 1946.651
#  > Model[[(0, 1, 2), (1, 0, 1, 12), 'c']] 2274.977
#  > Model[[(0, 1, 2), (1, 1, 0, 6), 'c']] 2097.392
#  > Model[[(0, 1, 2), (1, 0, 2, 6), 'c']] 2946.582
#  > Model[[(0, 1, 2), (1, 1, 1, 6), 'c']] 2268.911
#  > Model[[(0, 1, 2), (1, 1, 0, 12), 'c']] 2104.121
#  > Model[[(0, 1, 2), (1, 0, 2, 12), 'c']] 2681.329
#  > Model[[(0, 1, 2), (0, 1, 2, 12), 'c']] 414572517.481
#  > Model[[(0, 1, 2), (2, 0, 0, 6), 'c']] 2087.900
#  > Model[[(0, 1, 2), (1, 1, 2, 6), 'c']] 2370.662
#  > Model[[(0, 1, 2), (1, 1, 1, 12), 'c']] 1958.511
#  > Model[[(0, 1, 2), (2, 0, 1, 6), 'c']] 2414.513
#  > Model[[(0, 1, 2), (2, 0, 0, 12), 'c']] 2250.732
#  > Model[[(0, 1, 2), (2, 0, 2, 6), 'c']] 2230.192
#  > Model[[(0, 1, 2), (2, 0, 1, 12), 'c']] 2394.891
#  > Model[[(0, 1, 2), (2, 1, 0, 6), 'c']] 1994.089
#  > Model[[(0, 1, 2), (2, 0, 2, 12), 'c']] 2180.732
#  > Model[[(0, 1, 2), (2, 1, 1, 6), 'c']] 2307.270
#  > Model[[(0, 1, 2), (1, 1, 2, 12), 'c']] 2913416636316019.000
#  > Model[[(0, 1, 2), (2, 1, 0, 12), 'c']] 1937.754
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 't']] 4134.212
#  > Model[[(0, 1, 2), (0, 0, 0, 6), 't']] 4134.212
#  > Model[[(0, 1, 2), (0, 0, 0, 12), 't']] 4134.212
#  > Model[[(0, 1, 2), (2, 1, 2, 6), 'c']] 2274.744
#  > Model[[(0, 1, 2), (0, 0, 1, 6), 't']] 3918.789
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-23-20fceb7e65af> in grid_search(data, cfg_list, n_test, parallel)
#       6         executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
#       7         tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
# ----> 8         scores = executor(tasks)
#       9     else:
#      10         scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
#
# ~/miniconda3/envs/scorecard/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/envs/scorecard/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~/miniconda3/envs/scorecard/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/miniconda3/envs/scorecard/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/miniconda3/envs/scorecard/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/miniconda3/envs/scorecard/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# list top 3 configs
for cfg, error in scores[:3]:
print(cfg, error)
